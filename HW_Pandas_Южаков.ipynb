# %%
# Импорт библиотек
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dfl = pd.read_csv('data/lectures.csv', delimiter = ',')
dfl.shape
# Out:
# (418, 4)

# %%
dfl.head()
# Out:
#    lecture_id  tag  part           type_of
# 0          89  159     5           concept
# 1         100   70     1           concept
# 2         185   45     6           concept
# 3         192   79     5  solving question
# 4         317  156     5  solving question

# %%
dfl.describe()
# Out:
#          lecture_id         tag        part
# count    418.000000  418.000000  418.000000
# mean   16983.401914   94.480861    4.267943
# std     9426.164660   53.586487    1.872424
# min       89.000000    0.000000    1.000000
# 25%     9026.250000   50.250000    2.000000
# 50%    17161.500000   94.500000    5.000000
# 75%    24906.250000  140.000000    6.000000
# max    32736.000000  187.000000    7.000000

# %%
dfl.isna().sum()
# Out:
# lecture_id    0
# tag           0
# part          0
# type_of       0
# dtype: int64

# %%
dfl.duplicated().sum()
# Out:
# 0

# %%
dfl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   lecture_id  418 non-null    int64
#  1   tag         418 non-null    int64
#  2   part        418 non-null    int64
#  3   type_of     418 non-null    object
# dtypes: int64(3), object(1)
# memory usage: 13.2+ KB

# %%
dfl[['type_of', 'part', 'lecture_id']].groupby(['type_of','part'], as_index = False).count().sort_values(by = ['type_of', 'part'])
# Out:
#              type_of  part  lecture_id
# 0            concept     1          20
# 1            concept     2          18
# 2            concept     3           7
# 3            concept     4          19
# 4            concept     5          72
# 5            concept     6          63
# 6            concept     7          23
# 7          intention     2           7
# 8   solving question     1          34
# 9   solving question     2          31
# 10  solving question     3          12
# 11  solving question     4          12
# 12  solving question     5          69
# 13  solving question     6          19
# 14  solving question     7           9
# 15           starter     5           2
# 16           starter     6           1

# %%
sns.scatterplot(data = dfl, x = 'part', y = 'tag', hue = 'type_of')
# Out:
# <AxesSubplot: xlabel='part', ylabel='tag'>

# %%
sns.histplot(data = dfl, x = 'tag', hue = 'type_of')
# Out:
# <AxesSubplot: xlabel='tag', ylabel='Count'>

# %%
sns.histplot(data = dfl, x = 'part', hue = 'type_of', bins = 7)
# Out:
# <AxesSubplot: xlabel='part', ylabel='Count'>

# %%
dfq = pd.read_csv('data/questions.csv', delimiter = ',')
dfq.shape
# Out:
# (13523, 5)

# %%
dfq.head()
# Out:
#    question_id  bundle_id  correct_answer  part            tags
# 0            0          0               0     1   51 131 162 38
# 1            1          1               1     1       131 36 81
# 2            2          2               0     1  131 101 162 92
# 3            3          3               0     1  131 149 162 29
# 4            4          4               3     1    131 5 162 38

# %%
dfq.describe()
# Out:
#        question_id     bundle_id  correct_answer          part
# count  13523.00000  13523.000000    13523.000000  13523.000000
# mean    6761.00000   6760.510907        1.455298      4.264956
# std     3903.89818   3903.857783        1.149707      1.652553
# min        0.00000      0.000000        0.000000      1.000000
# 25%     3380.50000   3379.500000        0.000000      3.000000
# 50%     6761.00000   6761.000000        1.000000      5.000000
# 75%    10141.50000  10140.000000        3.000000      5.000000
# max    13522.00000  13522.000000        3.000000      7.000000

# %%
dfq.isna().sum()
# Out:
# question_id       0
# bundle_id         0
# correct_answer    0
# part              0
# tags              1
# dtype: int64

# %%
dfq[dfq.tags.isna()]
# Out:
#        question_id  bundle_id  correct_answer  part tags
# 10033        10033      10033               2     6  NaN

# %%
dfq.duplicated().sum()
# Out:
# 0

# %%
dfq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13523 entries, 0 to 13522
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   question_id     13523 non-null  int64
#  1   bundle_id       13523 non-null  int64
#  2   correct_answer  13523 non-null  int64
#  3   part            13523 non-null  int64
#  4   tags            13522 non-null  object
# dtypes: int64(4), object(1)
# memory usage: 528.4+ KB

# %%
dfq[['part', 'question_id']].groupby(['part'], as_index = False).count()
# Out:
#    part  question_id
# 0     1          992
# 1     2         1647
# 2     3         1562
# 3     4         1439
# 4     5         5511
# 5     6         1212
# 6     7         1160

# %%
sns.histplot(data = dfq, x = 'part', bins = 7)
# Out:
# <AxesSubplot: xlabel='part', ylabel='Count'>

# %%
df = pd.read_csv('data/train.csv', delimiter = ',', nrows = 1500000)
df.shape
# Out:
# (1500000, 10)

# %%
df.head()
# Out:
#    row_id  timestamp  user_id  content_id  content_type_id  task_container_id  \
# 0       0          0      115        5692                0                  1
# 1       1      56943      115        5716                0                  2
# 2       2     118363      115         128                0                  0
# 3       3     131167      115        7860                0                  3
# 4       4     137965      115        7922                0                  4
#
#    user_answer  answered_correctly  prior_question_elapsed_time  \
# 0            3                   1                          NaN
# 1            2                   1                      37000.0
# 2            0                   1                      55000.0
# 3            0                   1                      19000.0
# 4            1                   1                      11000.0
#
#   prior_question_had_explanation
# 0                            NaN
# 1                          False
# 2                          False
# 3                          False
# 4                          False

# %%
cat_columns = []
num_columns = []

for column_name in df.columns:
    if (df[column_name].dtypes == object):
        cat_columns += [column_name]
    else:
        num_columns += [column_name]

print('Категориальные данные:\t ',cat_columns, '\n Число столблцов =', len(cat_columns))
print('Числовые данные:\t ', num_columns, '\n Число столблцов =', len(num_columns))
# Out:
# Категориальные данные:	  ['prior_question_had_explanation']
#  Число столблцов = 1
# Числовые данные:	  ['row_id', 'timestamp', 'user_id', 'content_id', 'content_type_id', 'task_container_id', 'user_answer', 'answered_correctly', 'prior_question_elapsed_time']
#  Число столблцов = 9

# %%
df.describe()
# Out:
#              row_id     timestamp       user_id    content_id  \
# count  1.500000e+06  1.500000e+06  1.500000e+06  1.500000e+06
# mean   7.499995e+05  7.164311e+09  1.554237e+07  5.204291e+03
# std    4.330128e+05  1.053062e+10  9.233238e+06  3.882724e+03
# min    0.000000e+00  0.000000e+00  1.150000e+02  0.000000e+00
# 25%    3.749998e+05  5.145690e+08  7.171715e+06  2.025000e+03
# 50%    7.499995e+05  2.636763e+09  1.556872e+07  5.010000e+03
# 75%    1.124999e+06  9.573303e+09  2.350614e+07  7.397000e+03
# max    1.499999e+06  7.809200e+10  3.156632e+07  3.273600e+04
#
#        content_type_id  task_container_id   user_answer  answered_correctly  \
# count     1.500000e+06       1.500000e+06  1.500000e+06        1.500000e+06
# mean      1.994467e-02       8.004560e+02  1.375011e+00        6.195200e-01
# std       1.398102e-01       1.030197e+03  1.194656e+00        5.249805e-01
# min       0.000000e+00       0.000000e+00 -1.000000e+00       -1.000000e+00
# 25%       0.000000e+00       1.070000e+02  0.000000e+00        0.000000e+00
# 50%       0.000000e+00       3.830000e+02  1.000000e+00        1.000000e+00
# 75%       0.000000e+00       1.104000e+03  3.000000e+00        1.000000e+00
# max       1.000000e+00       7.739000e+03  3.000000e+00        1.000000e+00
#
#        prior_question_elapsed_time
# count                 1.464333e+06
# mean                  2.535047e+04
# std                   1.956775e+04
# min                   0.000000e+00
# 25%                   1.600000e+04
# 50%                   2.100000e+04
# 75%                   2.975000e+04
# max                   3.000000e+05

# %%
num_col_big = ['row_id', 'timestamp', 'user_id', 'content_id', 'task_container_id', 'prior_question_elapsed_time']
width = 2
height = int(np.ceil(len(num_col_big) / width))
fig, ax = plt.subplots(nrows = height, ncols = width, figsize = (12, 10))

for idx, column_name in enumerate(num_col_big):
    plt.subplot(height, width, idx + 1)
    sns.histplot(data = df, x = column_name, bins = 20, color = 'blue')

# %%
num_col_small = ['content_type_id', 'user_answer', 'answered_correctly']
width = 3
height = int(np.ceil(len(num_col_small) / width))
fig, ax = plt.subplots(nrows = height, ncols = width, figsize = (15, 4))

for idx, column_name in enumerate(num_col_small):
    plt.subplot(height, width, idx + 1)
    sns.histplot(data = df, x = column_name, bins = 5, color = 'purple')

# %%
df.isna().sum()
# Out:
# row_id                                0
# timestamp                             0
# user_id                               0
# content_id                            0
# content_type_id                       0
# task_container_id                     0
# user_answer                           0
# answered_correctly                    0
# prior_question_elapsed_time       35667
# prior_question_had_explanation     5750
# dtype: int64

# %%
df[df.prior_question_elapsed_time.isna()]
# Out:
#           row_id   timestamp   user_id  content_id  content_type_id  \
# 0              0           0       115        5692                0
# 46            46           0       124        7900                0
# 76            76           0      2746        5273                0
# 89            89      653762      2746        6808                1
# 96            96           0      5382        5000                0
# ...          ...         ...       ...         ...              ...
# 1499060  1499060  4675035868  31566318        7008                1
# 1499153  1499153  4767796153  31566318       24335                1
# 1499230  1499230  4855040695  31566318       24558                1
# 1499310  1499310  4943699956  31566318       16363                1
# 1499352  1499352  5024305786  31566318       14019                1
#
#          task_container_id  user_answer  answered_correctly  \
# 0                        1            3                   1
# 46                       0            0                   1
# 76                       0            1                   0
# 89                      14           -1                  -1
# 96                       0            0                   1
# ...                    ...          ...                 ...
# 1499060               4343           -1                  -1
# 1499153               4391           -1                  -1
# 1499230               4430           -1                  -1
# 1499310               4456           -1                  -1
# 1499352               4472           -1                  -1
#
#          prior_question_elapsed_time prior_question_had_explanation
# 0                                NaN                            NaN
# 46                               NaN                            NaN
# 76                               NaN                            NaN
# 89                               NaN                          False
# 96                               NaN                            NaN
# ...                              ...                            ...
# 1499060                          NaN                          False
# 1499153                          NaN                          False
# 1499230                          NaN                          False
# 1499310                          NaN                          False
# 1499352                          NaN                          False
#
# [35667 rows x 10 columns]

# %%
df[df.prior_question_had_explanation.isna()]
# Out:
#           row_id  timestamp   user_id  content_id  content_type_id  \
# 0              0          0       115        5692                0
# 46            46          0       124        7900                0
# 76            76          0      2746        5273                0
# 96            96          0      5382        5000                0
# 224          224          0      8623        3915                0
# ...          ...        ...       ...         ...              ...
# 1492180  1492180          0  31514265        4476                0
# 1492323  1492323          0  31526967        4848                0
# 1492626  1492626          0  31536921        4425                0
# 1492650  1492650          0  31563425        5685                0
# 1492666  1492666          0  31566318        3879                0
#
#          task_container_id  user_answer  answered_correctly  \
# 0                        1            3                   1
# 46                       0            0                   1
# 76                       0            1                   0
# 96                       0            0                   1
# 224                      0            3                   1
# ...                    ...          ...                 ...
# 1492180                  0            0                   0
# 1492323                  0            0                   1
# 1492626                  0            2                   0
# 1492650                  0            2                   1
# 1492666                  0            0                   0
#
#          prior_question_elapsed_time prior_question_had_explanation
# 0                                NaN                            NaN
# 46                               NaN                            NaN
# 76                               NaN                            NaN
# 96                               NaN                            NaN
# 224                              NaN                            NaN
# ...                              ...                            ...
# 1492180                          NaN                            NaN
# 1492323                          NaN                            NaN
# 1492626                          NaN                            NaN
# 1492650                          NaN                            NaN
# 1492666                          NaN                            NaN
#
# [5750 rows x 10 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500000 entries, 0 to 1499999
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   row_id                          1500000 non-null  int64
#  1   timestamp                       1500000 non-null  int64
#  2   user_id                         1500000 non-null  int64
#  3   content_id                      1500000 non-null  int64
#  4   content_type_id                 1500000 non-null  int64
#  5   task_container_id               1500000 non-null  int64
#  6   user_answer                     1500000 non-null  int64
#  7   answered_correctly              1500000 non-null  int64
#  8   prior_question_elapsed_time     1464333 non-null  float64
#  9   prior_question_had_explanation  1494250 non-null  object
# dtypes: float64(1), int64(8), object(1)
# memory usage: 114.4+ MB

# %%
df = df.drop('row_id', axis = 1)
df['timestamp'] = df['timestamp'].astype('uint64')
df['user_id'] = df['user_id'].astype('uint32')
df['content_id'] = df['content_id'].astype('uint16')
df['content_type_id'] = df['content_type_id'].astype('int8')
df['task_container_id'] = df['task_container_id'].astype('uint16')
df['user_answer'] = df['user_answer'].astype('int8')
df['answered_correctly'] = df['answered_correctly'].astype('int8')
df['prior_question_elapsed_time'] = df['prior_question_elapsed_time'].astype('float32')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500000 entries, 0 to 1499999
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   timestamp                       1500000 non-null  uint64
#  1   user_id                         1500000 non-null  uint32
#  2   content_id                      1500000 non-null  uint16
#  3   content_type_id                 1500000 non-null  int8
#  4   task_container_id               1500000 non-null  uint16
#  5   user_answer                     1500000 non-null  int8
#  6   answered_correctly              1500000 non-null  int8
#  7   prior_question_elapsed_time     1464333 non-null  float32
#  8   prior_question_had_explanation  1494250 non-null  object
# dtypes: float32(1), int8(3), object(1), uint16(2), uint32(1), uint64(1)
# memory usage: 44.3+ MB

# %%
# После очистки данных датафрейм занимает 44 Мб (было 114 Мб)

# %%
cm = sns.color_palette("vlag", as_cmap = True)
df_corr = df.loc[:,['timestamp', 'user_id', 'content_id', 'content_type_id', 'task_container_id', 'user_answer', 'answered_correctly', 'prior_question_elapsed_time']]
df_corr.corr().style.background_gradient(cmap = cm, vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_8177e_row0_col0, #T_8177e_row1_col1, #T_8177e_row2_col2, #T_8177e_row3_col3, #T_8177e_row4_col4, #T_8177e_row5_col5, #T_8177e_row6_col6, #T_8177e_row7_col7 {
#   background-color: #a9373b;
#   color: #f1f1f1;
# }
# #T_8177e_row0_col1, #T_8177e_row1_col0, #T_8177e_row1_col4, #T_8177e_row4_col1, #T_8177e_row4_col7, #T_8177e_row7_col4 {
#   background-color: #f9f5f5;
#   color: #000000;
# }
# #T_8177e_row0_col2, #T_8177e_row2_col0 {
#   background-color: #faf2f1;
#   color: #000000;
# }
# #T_8177e_row0_col3, #T_8177e_row1_col3, #T_8177e_row1_col7, #T_8177e_row3_col0, #T_8177e_row3_col1, #T_8177e_row4_col5, #T_8177e_row5_col4, #T_8177e_row5_col7, #T_8177e_row6_col7, #T_8177e_row7_col1, #T_8177e_row7_col5, #T_8177e_row7_col6 {
#   background-color: #faf5f4;
#   color: #000000;
# }
# #T_8177e_row0_col4, #T_8177e_row4_col0 {
#   background-color: #ddafad;
#   color: #000000;
# }
# #T_8177e_row0_col5, #T_8177e_row1_col2, #T_8177e_row1_col5, #T_8177e_row1_col6, #T_8177e_row2_col1, #T_8177e_row3_col4, #T_8177e_row4_col3, #T_8177e_row5_col0, #T_8177e_row5_col1, #T_8177e_row6_col1 {
#   background-color: #faf5f5;
#   color: #000000;
# }
# #T_8177e_row0_col6, #T_8177e_row0_col7, #T_8177e_row6_col0, #T_8177e_row7_col0 {
#   background-color: #faf4f3;
#   color: #000000;
# }
# #T_8177e_row2_col3, #T_8177e_row3_col2 {
#   background-color: #daa8a5;
#   color: #000000;
# }
# #T_8177e_row2_col4, #T_8177e_row4_col2, #T_8177e_row4_col6, #T_8177e_row6_col4 {
#   background-color: #faf0ef;
#   color: #000000;
# }
# #T_8177e_row2_col5, #T_8177e_row5_col2 {
#   background-color: #ebeaee;
#   color: #000000;
# }
# #T_8177e_row2_col6, #T_8177e_row6_col2 {
#   background-color: #d9dce5;
#   color: #000000;
# }
# #T_8177e_row2_col7, #T_8177e_row7_col2 {
#   background-color: #f1dddb;
#   color: #000000;
# }
# #T_8177e_row3_col5, #T_8177e_row5_col3 {
#   background-color: #c7cedc;
#   color: #000000;
# }
# #T_8177e_row3_col6, #T_8177e_row6_col3 {
#   background-color: #a7b6ce;
#   color: #000000;
# }
# #T_8177e_row3_col7, #T_8177e_row7_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_8177e_row5_col6, #T_8177e_row6_col5 {
#   background-color: #f3e2e0;
#   color: #000000;
# }
# </style>
# <table id="T_8177e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8177e_level0_col0" class="col_heading level0 col0" >timestamp</th>
#       <th id="T_8177e_level0_col1" class="col_heading level0 col1" >user_id</th>
#       <th id="T_8177e_level0_col2" class="col_heading level0 col2" >content_id</th>
#       <th id="T_8177e_level0_col3" class="col_heading level0 col3" >content_type_id</th>
#       <th id="T_8177e_level0_col4" class="col_heading level0 col4" >task_container_id</th>
#       <th id="T_8177e_level0_col5" class="col_heading level0 col5" >user_answer</th>
#       <th id="T_8177e_level0_col6" class="col_heading level0 col6" >answered_correctly</th>
#       <th id="T_8177e_level0_col7" class="col_heading level0 col7" >prior_question_elapsed_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8177e_level0_row0" class="row_heading level0 row0" >timestamp</th>
#       <td id="T_8177e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8177e_row0_col1" class="data row0 col1" >-0.028015</td>
#       <td id="T_8177e_row0_col2" class="data row0 col2" >0.041457</td>
#       <td id="T_8177e_row0_col3" class="data row0 col3" >0.008534</td>
#       <td id="T_8177e_row0_col4" class="data row0 col4" >0.375815</td>
#       <td id="T_8177e_row0_col5" class="data row0 col5" >-0.002241</td>
#       <td id="T_8177e_row0_col6" class="data row0 col6" >0.021893</td>
#       <td id="T_8177e_row0_col7" class="data row0 col7" >0.018206</td>
#     </tr>
#     <tr>
#       <th id="T_8177e_level0_row1" class="row_heading level0 row1" >user_id</th>
#       <td id="T_8177e_row1_col0" class="data row1 col0" >-0.028015</td>
#       <td id="T_8177e_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_8177e_row1_col2" class="data row1 col2" >-0.012670</td>
#       <td id="T_8177e_row1_col3" class="data row1 col3" >0.002128</td>
#       <td id="T_8177e_row1_col4" class="data row1 col4" >-0.026350</td>
#       <td id="T_8177e_row1_col5" class="data row1 col5" >-0.000927</td>
#       <td id="T_8177e_row1_col6" class="data row1 col6" >-0.000515</td>
#       <td id="T_8177e_row1_col7" class="data row1 col7" >0.007701</td>
#     </tr>
#     <tr>
#       <th id="T_8177e_level0_row2" class="row_heading level0 row2" >content_id</th>
#       <td id="T_8177e_row2_col0" class="data row2 col0" >0.041457</td>
#       <td id="T_8177e_row2_col1" class="data row2 col1" >-0.012670</td>
#       <td id="T_8177e_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_8177e_row2_col3" class="data row2 col3" >0.420060</td>
#       <td id="T_8177e_row2_col4" class="data row2 col4" >0.051465</td>
#       <td id="T_8177e_row2_col5" class="data row2 col5" >-0.110519</td>
#       <td id="T_8177e_row2_col6" class="data row2 col6" >-0.201972</td>
#       <td id="T_8177e_row2_col7" class="data row2 col7" >0.153409</td>
#     </tr>
#     <tr>
#       <th id="T_8177e_level0_row3" class="row_heading level0 row3" >content_type_id</th>
#       <td id="T_8177e_row3_col0" class="data row3 col0" >0.008534</td>
#       <td id="T_8177e_row3_col1" class="data row3 col1" >0.002128</td>
#       <td id="T_8177e_row3_col2" class="data row3 col2" >0.420060</td>
#       <td id="T_8177e_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_8177e_row3_col4" class="data row3 col4" >-0.010293</td>
#       <td id="T_8177e_row3_col5" class="data row3 col5" >-0.283603</td>
#       <td id="T_8177e_row3_col6" class="data row3 col6" >-0.440080</td>
#       <td id="T_8177e_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8177e_level0_row4" class="row_heading level0 row4" >task_container_id</th>
#       <td id="T_8177e_row4_col0" class="data row4 col0" >0.375815</td>
#       <td id="T_8177e_row4_col1" class="data row4 col1" >-0.026350</td>
#       <td id="T_8177e_row4_col2" class="data row4 col2" >0.051465</td>
#       <td id="T_8177e_row4_col3" class="data row4 col3" >-0.010293</td>
#       <td id="T_8177e_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_8177e_row4_col5" class="data row4 col5" >0.008820</td>
#       <td id="T_8177e_row4_col6" class="data row4 col6" >0.046935</td>
#       <td id="T_8177e_row4_col7" class="data row4 col7" >-0.030985</td>
#     </tr>
#     <tr>
#       <th id="T_8177e_level0_row5" class="row_heading level0 row5" >user_answer</th>
#       <td id="T_8177e_row5_col0" class="data row5 col0" >-0.002241</td>
#       <td id="T_8177e_row5_col1" class="data row5 col1" >-0.000927</td>
#       <td id="T_8177e_row5_col2" class="data row5 col2" >-0.110519</td>
#       <td id="T_8177e_row5_col3" class="data row5 col3" >-0.283603</td>
#       <td id="T_8177e_row5_col4" class="data row5 col4" >0.008820</td>
#       <td id="T_8177e_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_8177e_row5_col6" class="data row5 col6" >0.127461</td>
#       <td id="T_8177e_row5_col7" class="data row5 col7" >0.014551</td>
#     </tr>
#     <tr>
#       <th id="T_8177e_level0_row6" class="row_heading level0 row6" >answered_correctly</th>
#       <td id="T_8177e_row6_col0" class="data row6 col0" >0.021893</td>
#       <td id="T_8177e_row6_col1" class="data row6 col1" >-0.000515</td>
#       <td id="T_8177e_row6_col2" class="data row6 col2" >-0.201972</td>
#       <td id="T_8177e_row6_col3" class="data row6 col3" >-0.440080</td>
#       <td id="T_8177e_row6_col4" class="data row6 col4" >0.046935</td>
#       <td id="T_8177e_row6_col5" class="data row6 col5" >0.127461</td>
#       <td id="T_8177e_row6_col6" class="data row6 col6" >1.000000</td>
#       <td id="T_8177e_row6_col7" class="data row6 col7" >0.000644</td>
#     </tr>
#     <tr>
#       <th id="T_8177e_level0_row7" class="row_heading level0 row7" >prior_question_elapsed_time</th>
#       <td id="T_8177e_row7_col0" class="data row7 col0" >0.018206</td>
#       <td id="T_8177e_row7_col1" class="data row7 col1" >0.007701</td>
#       <td id="T_8177e_row7_col2" class="data row7 col2" >0.153409</td>
#       <td i

# %%
df_corr['cor_ratio'] = df_corr.answered_correctly / df_corr.user_answer
df_corr.corr().style.background_gradient(cmap = cm, vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_084c4_row0_col0, #T_084c4_row1_col1, #T_084c4_row2_col2, #T_084c4_row3_col3, #T_084c4_row4_col4, #T_084c4_row5_col5, #T_084c4_row6_col6, #T_084c4_row7_col7, #T_084c4_row8_col8 {
#   background-color: #a9373b;
#   color: #f1f1f1;
# }
# #T_084c4_row0_col1, #T_084c4_row1_col0, #T_084c4_row1_col4, #T_084c4_row4_col1, #T_084c4_row4_col7, #T_084c4_row7_col4 {
#   background-color: #f9f5f5;
#   color: #000000;
# }
# #T_084c4_row0_col2, #T_084c4_row2_col0 {
#   background-color: #faf2f1;
#   color: #000000;
# }
# #T_084c4_row0_col3, #T_084c4_row1_col3, #T_084c4_row1_col7, #T_084c4_row1_col8, #T_084c4_row3_col0, #T_084c4_row3_col1, #T_084c4_row4_col5, #T_084c4_row5_col4, #T_084c4_row5_col7, #T_084c4_row6_col7, #T_084c4_row7_col1, #T_084c4_row7_col5, #T_084c4_row7_col6, #T_084c4_row8_col1 {
#   background-color: #faf5f4;
#   color: #000000;
# }
# #T_084c4_row0_col4, #T_084c4_row4_col0 {
#   background-color: #ddafad;
#   color: #000000;
# }
# #T_084c4_row0_col5, #T_084c4_row1_col2, #T_084c4_row1_col5, #T_084c4_row1_col6, #T_084c4_row2_col1, #T_084c4_row3_col4, #T_084c4_row4_col3, #T_084c4_row5_col0, #T_084c4_row5_col1, #T_084c4_row6_col1, #T_084c4_row7_col8, #T_084c4_row8_col7 {
#   background-color: #faf5f5;
#   color: #000000;
# }
# #T_084c4_row0_col6, #T_084c4_row0_col7, #T_084c4_row6_col0, #T_084c4_row7_col0 {
#   background-color: #faf4f3;
#   color: #000000;
# }
# #T_084c4_row0_col8, #T_084c4_row8_col0 {
#   background-color: #faf3f3;
#   color: #000000;
# }
# #T_084c4_row2_col3, #T_084c4_row3_col2 {
#   background-color: #daa8a5;
#   color: #000000;
# }
# #T_084c4_row2_col4, #T_084c4_row4_col2, #T_084c4_row4_col6, #T_084c4_row6_col4 {
#   background-color: #faf0ef;
#   color: #000000;
# }
# #T_084c4_row2_col5, #T_084c4_row5_col2 {
#   background-color: #ebeaee;
#   color: #000000;
# }
# #T_084c4_row2_col6, #T_084c4_row6_col2 {
#   background-color: #d9dce5;
#   color: #000000;
# }
# #T_084c4_row2_col7, #T_084c4_row7_col2 {
#   background-color: #f1dddb;
#   color: #000000;
# }
# #T_084c4_row2_col8, #T_084c4_row8_col2 {
#   background-color: #f7ebea;
#   color: #000000;
# }
# #T_084c4_row3_col5, #T_084c4_row5_col3 {
#   background-color: #c7cedc;
#   color: #000000;
# }
# #T_084c4_row3_col6, #T_084c4_row6_col3 {
#   background-color: #a7b6ce;
#   color: #000000;
# }
# #T_084c4_row3_col7, #T_084c4_row7_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_084c4_row3_col8, #T_084c4_row8_col3 {
#   background-color: #e8cac8;
#   color: #000000;
# }
# #T_084c4_row4_col8, #T_084c4_row8_col4 {
#   background-color: #faf3f2;
#   color: #000000;
# }
# #T_084c4_row5_col6, #T_084c4_row6_col5 {
#   background-color: #f3e2e0;
#   color: #000000;
# }
# #T_084c4_row5_col8, #T_084c4_row8_col5 {
#   background-color: #95a9c8;
#   color: #f1f1f1;
# }
# #T_084c4_row6_col8, #T_084c4_row8_col6 {
#   background-color: #d19290;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_084c4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_084c4_level0_col0" class="col_heading level0 col0" >timestamp</th>
#       <th id="T_084c4_level0_col1" class="col_heading level0 col1" >user_id</th>
#       <th id="T_084c4_level0_col2" class="col_heading level0 col2" >content_id</th>
#       <th id="T_084c4_level0_col3" class="col_heading level0 col3" >content_type_id</th>
#       <th id="T_084c4_level0_col4" class="col_heading level0 col4" >task_container_id</th>
#       <th id="T_084c4_level0_col5" class="col_heading level0 col5" >user_answer</th>
#       <th id="T_084c4_level0_col6" class="col_heading level0 col6" >answered_correctly</th>
#       <th id="T_084c4_level0_col7" class="col_heading level0 col7" >prior_question_elapsed_time</th>
#       <th id="T_084c4_level0_col8" class="col_heading level0 col8" >cor_ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_084c4_level0_row0" class="row_heading level0 row0" >timestamp</th>
#       <td id="T_084c4_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_084c4_row0_col1" class="data row0 col1" >-0.028015</td>
#       <td id="T_084c4_row0_col2" class="data row0 col2" >0.041457</td>
#       <td id="T_084c4_row0_col3" class="data row0 col3" >0.008534</td>
#       <td id="T_084c4_row0_col4" class="data row0 col4" >0.375815</td>
#       <td id="T_084c4_row0_col5" class="data row0 col5" >-0.002241</td>
#       <td id="T_084c4_row0_col6" class="data row0 col6" >0.021893</td>
#       <td id="T_084c4_row0_col7" class="data row0 col7" >0.018206</td>
#       <td id="T_084c4_row0_col8" class="data row0 col8" >0.027825</td>
#     </tr>
#     <tr>
#       <th id="T_084c4_level0_row1" class="row_heading level0 row1" >user_id</th>
#       <td id="T_084c4_row1_col0" class="data row1 col0" >-0.028015</td>
#       <td id="T_084c4_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_084c4_row1_col2" class="data row1 col2" >-0.012670</td>
#       <td id="T_084c4_row1_col3" class="data row1 col3" >0.002128</td>
#       <td id="T_084c4_row1_col4" class="data row1 col4" >-0.026350</td>
#       <td id="T_084c4_row1_col5" class="data row1 col5" >-0.000927</td>
#       <td id="T_084c4_row1_col6" class="data row1 col6" >-0.000515</td>
#       <td id="T_084c4_row1_col7" class="data row1 col7" >0.007701</td>
#       <td id="T_084c4_row1_col8" class="data row1 col8" >0.000709</td>
#     </tr>
#     <tr>
#       <th id="T_084c4_level0_row2" class="row_heading level0 row2" >content_id</th>
#       <td id="T_084c4_row2_col0" class="data row2 col0" >0.041457</td>
#       <td id="T_084c4_row2_col1" class="data row2 col1" >-0.012670</td>
#       <td id="T_084c4_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_084c4_row2_col3" class="data row2 col3" >0.420060</td>
#       <td id="T_084c4_row2_col4" class="data row2 col4" >0.051465</td>
#       <td id="T_084c4_row2_col5" class="data row2 col5" >-0.110519</td>
#       <td id="T_084c4_row2_col6" class="data row2 col6" >-0.201972</td>
#       <td id="T_084c4_row2_col7" class="data row2 col7" >0.153409</td>
#       <td id="T_084c4_row2_col8" class="data row2 col8" >0.082783</td>
#     </tr>
#     <tr>
#       <th id="T_084c4_level0_row3" class="row_heading level0 row3" >content_type_id</th>
#       <td id="T_084c4_row3_col0" class="data row3 col0" >0.008534</td>
#       <td id="T_084c4_row3_col1" class="data row3 col1" >0.002128</td>
#       <td id="T_084c4_row3_col2" class="data row3 col2" >0.420060</td>
#       <td id="T_084c4_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_084c4_row3_col4" class="data row3 col4" >-0.010293</td>
#       <td id="T_084c4_row3_col5" class="data row3 col5" >-0.283603</td>
#       <td id="T_084c4_row3_col6" class="data row3 col6" >-0.440080</td>
#       <td id="T_084c4_row3_col7" class="data row3 col7" >nan</td>
#       <td id="T_084c4_row3_col8" class="data row3 col8" >0.249284</td>
#     </tr>
#     <tr>
#       <th id="T_084c4_level0_row4" class="row_heading level0 row4" >task_container_id</th>
#       <td id="T_084c4_row4_col0" class="data row4 col0" >0.375815</td>
#       <td id="T_084c4_row4_col1" class="data row4 col1" >-0.026350</td>
#       <td id="T_084c4_row4_col2" class="data row4 col2" >0.051465</td>
#       <td id="T_084c4_row4_col3" class="data row4 col3" >-0.010293</td>
#       <td id="T_084c4_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_084c4_row4_col5" class="data row4 col5" >0.008820</td>
#       <td id="T_084c4_row4_col6" class="data row4 col6" >0.046935</td>
#       <td id="T_084c4_row4_col7" class="data row4 col7" >-0.030985</td>
#       <td id="T_084c4_row4_col8" class="data row4 col8" >0.032993</td>
#     </tr>
#     <tr>
#       <th id="T_084c4_level0_row5" class="row_heading level0 row5" >user_answer</th>
#       <td id="T_084c4_row5_col0" class="data row5 col0" >-0.002241</td>
#       <td id="T_084c4_row5_col1" class="data row5 col1" >-0.000927</td>
#       <td id="T_084c4_row5_col2" class="data row5 col2" >-0.110519</td>
#       <td id="T_084c4_row5_col3" class="data row5 col3" >-0.283603</td>
#       <td id="T_084c4_row5_col4" class="data row5 col4" >0.008820</td>
#       <td id="T_084c4_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_084c4_row5_col6" class="data row5 col6" >0.127461</td>
#       <td id="T_084

# %%
df_corr.drop(df_corr.columns[[0, 1, 2, 4, 7]], axis = 1, inplace = True)
df_corr.corr().style.background_gradient(cmap = cm, vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_bc7cc_row0_col0, #T_bc7cc_row1_col1, #T_bc7cc_row2_col2, #T_bc7cc_row3_col3 {
#   background-color: #a9373b;
#   color: #f1f1f1;
# }
# #T_bc7cc_row0_col1, #T_bc7cc_row1_col0 {
#   background-color: #c7cedc;
#   color: #000000;
# }
# #T_bc7cc_row0_col2, #T_bc7cc_row2_col0 {
#   background-color: #a7b6ce;
#   color: #000000;
# }
# #T_bc7cc_row0_col3, #T_bc7cc_row3_col0 {
#   background-color: #e8cac8;
#   color: #000000;
# }
# #T_bc7cc_row1_col2, #T_bc7cc_row2_col1 {
#   background-color: #f3e2e0;
#   color: #000000;
# }
# #T_bc7cc_row1_col3, #T_bc7cc_row3_col1 {
#   background-color: #95a9c8;
#   color: #f1f1f1;
# }
# #T_bc7cc_row2_col3, #T_bc7cc_row3_col2 {
#   background-color: #d19290;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bc7cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc7cc_level0_col0" class="col_heading level0 col0" >content_type_id</th>
#       <th id="T_bc7cc_level0_col1" class="col_heading level0 col1" >user_answer</th>
#       <th id="T_bc7cc_level0_col2" class="col_heading level0 col2" >answered_correctly</th>
#       <th id="T_bc7cc_level0_col3" class="col_heading level0 col3" >cor_ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc7cc_level0_row0" class="row_heading level0 row0" >content_type_id</th>
#       <td id="T_bc7cc_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_bc7cc_row0_col1" class="data row0 col1" >-0.283603</td>
#       <td id="T_bc7cc_row0_col2" class="data row0 col2" >-0.440080</td>
#       <td id="T_bc7cc_row0_col3" class="data row0 col3" >0.249284</td>
#     </tr>
#     <tr>
#       <th id="T_bc7cc_level0_row1" class="row_heading level0 row1" >user_answer</th>
#       <td id="T_bc7cc_row1_col0" class="data row1 col0" >-0.283603</td>
#       <td id="T_bc7cc_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_bc7cc_row1_col2" class="data row1 col2" >0.127461</td>
#       <td id="T_bc7cc_row1_col3" class="data row1 col3" >-0.528965</td>
#     </tr>
#     <tr>
#       <th id="T_bc7cc_level0_row2" class="row_heading level0 row2" >answered_correctly</th>
#       <td id="T_bc7cc_row2_col0" class="data row2 col0" >-0.440080</td>
#       <td id="T_bc7cc_row2_col1" class="data row2 col1" >0.127461</td>
#       <td id="T_bc7cc_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_bc7cc_row2_col3" class="data row2 col3" >0.529504</td>
#     </tr>
#     <tr>
#       <th id="T_bc7cc_level0_row3" class="row_heading level0 row3" >cor_ratio</th>
#       <td id="T_bc7cc_row3_col0" class="data row3 col0" >0.249284</td>
#       <td id="T_bc7cc_row3_col1" class="data row3 col1" >-0.528965</td>
#       <td id="T_bc7cc_row3_col2" class="data row3 col2" >0.529504</td>
#       <td id="T_bc7cc_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.histplot(data = df_corr, x = 'cor_ratio', hue = 'content_type_id', bins = 10)
# Out:
# <AxesSubplot: xlabel='cor_ratio', ylabel='Count'>

# %%
df.agg({'user_id': pd.Series.nunique})
# Out:
# user_id    5760
# dtype: int64

# %%
us_a = df[['user_id', 'user_answer', 'answered_correctly']].groupby(['user_id'], as_index = False).sum()
us_a.head()
# Out:
#    user_id  user_answer  answered_correctly
# 0      115           72                  32
# 1      124           49                   7
# 2     2746           31                  10
# 3     5382          169                  81
# 4     8623          149                  67

# %%
us_a.describe()
# Out:
#             user_id   user_answer  answered_correctly
# count  5.760000e+03   5760.000000         5760.000000
# mean   1.578159e+07    358.075694          161.333333
# std    9.039642e+06    983.442162          466.164089
# min    1.150000e+02      1.000000           -2.000000
# 25%    7.997718e+06     37.000000           11.000000
# 50%    1.571119e+07     60.000000           23.000000
# 75%    2.367266e+07    225.250000           97.000000
# max    3.156632e+07  16907.000000         7613.000000

# %%
def rem_emission(df, col, k_std):
        mean = df[col].mean()
        std_o = df[col].std()
        return df[(df[col] <= mean + (k_std * std_o))]

us_a = rem_emission(us_a, 'user_answer', 1)
us_a['cor_ratio'] = us_a.answered_correctly / us_a.user_answer
us_a
# Out:
#        user_id  user_answer  answered_correctly  cor_ratio
# 0          115           72                  32   0.444444
# 1          124           49                   7   0.142857
# 2         2746           31                  10   0.322581
# 3         5382          169                  81   0.479290
# 4         8623          149                  67   0.449664
# ...        ...          ...                 ...        ...
# 5754  31500742          670                 308   0.459701
# 5755  31514265          170                 103   0.605882
# 5756  31526967          389                 193   0.496144
# 5757  31536921           38                  12   0.315789
# 5758  31563425           21                  12   0.571429
#
# [5406 rows x 4 columns]

# %%
us_a.describe()
# Out:
#             user_id  user_answer  answered_correctly    cor_ratio
# count  5.406000e+03  5406.000000         5406.000000  5406.000000
# mean   1.580327e+07   160.497780           68.812616     0.384298
# std    9.035491e+06   237.949564          110.505299     0.132300
# min    1.150000e+02     1.000000           -2.000000    -0.017241
# 25%    8.034505e+06    36.000000           11.000000     0.292683
# 50%    1.575568e+07    55.000000           21.000000     0.393075
# 75%    2.368764e+07   155.000000           67.000000     0.471360
# max    3.156342e+07  1335.000000          759.000000     1.750000

# %%
a_per_user_med = us_a.user_answer.median()
print('Медианное значение количества ответов студентов: ', a_per_user_med)
# Out:
# Медианное значение количества ответов студентов:  55.0

# %%
sns.histplot(data = us_a, x = 'user_answer')
# Out:
# <AxesSubplot: xlabel='user_answer', ylabel='Count'>

# %%
sns.histplot(data = us_a, x = 'user_answer', log_scale = True, color = 'purple')
# Out:
# <AxesSubplot: xlabel='user_answer', ylabel='Count'>

# %%
print(us_a.query('user_answer > 55')['cor_ratio'].median())
us_a.query('user_answer > 55')['cor_ratio'].hist(bins = 50, color = 'blue')
# Out:
# 0.43010752688172044
# <AxesSubplot: >

# %%
print(us_a.query('user_answer > 151')['cor_ratio'].median())
us_a.query('user_answer > 151')['cor_ratio'].hist(bins = 50, color = 'red')
# Out:
# 0.45052225002720053
# <AxesSubplot: >

# %%
print(us_a.query('user_answer > 500')['cor_ratio'].median())
us_a.query('user_answer > 500')['cor_ratio'].hist(bins = 50, color = 'orange')
# Out:
# 0.456752655538695
# <AxesSubplot: >

# %%
print(us_a.query('user_answer < 50')['cor_ratio'].median())
us_a.query('user_answer < 50')['cor_ratio'].hist(bins = 50, color = 'yellow')
# Out:
# 0.3333333333333333
# <AxesSubplot: >

# %%
corr_look = df[['user_id', 'user_answer', 'answered_correctly', 'timestamp', \
    'prior_question_elapsed_time']].groupby(['user_id'], as_index = False).sum()
corr_look['timestamp_ratio'] = corr_look['timestamp'] / corr_look['user_answer']
corr_look['elapsed_time_ratio'] = corr_look['prior_question_elapsed_time'] / corr_look['user_answer']
corr_look['cor_ratio'] = corr_look.answered_correctly / corr_look.user_answer
corr_look.drop(corr_look.columns[[0, 2, 3, 4]], axis = 1, inplace = True)
corr_look = rem_emission(corr_look, 'user_answer', 1)
corr_look
# Out:
#       user_answer  timestamp_ratio  elapsed_time_ratio  cor_ratio
# 0              72     6.524638e+07        12458.319444   0.444444
# 1              49     2.252203e+05        11122.387755   0.142857
# 2              31     2.472123e+05        10483.870968   0.322581
# 3             169     2.879101e+08        26449.704142   0.479290
# 4             149     2.615750e+08        18923.489933   0.449664
# ...           ...              ...                 ...        ...
# 5754          670     7.400699e+08        13309.200000   0.459701
# 5755          170     1.484667e+08        20560.976471   0.605882
# 5756          389     1.580026e+09        18931.089974   0.496144
# 5757           38     4.576848e+07        15421.052632   0.315789
# 5758           21     2.227479e+05        11952.380952   0.571429
#
# [5406 rows x 4 columns]

# %%
sns.regplot(data = corr_look, x = 'user_answer', y = 'timestamp_ratio', color = 'red')
# Out:
# <AxesSubplot: xlabel='user_answer', ylabel='timestamp_ratio'>

# %%
sns.regplot(data = corr_look, x = 'user_answer', y = 'elapsed_time_ratio', color = 'orange')
# Out:
# <AxesSubplot: xlabel='user_answer', ylabel='elapsed_time_ratio'>

# %%
sns.regplot(data = corr_look, x = 'timestamp_ratio', y = 'cor_ratio', color = 'brown')
# Out:
# <AxesSubplot: xlabel='timestamp_ratio', ylabel='cor_ratio'>

# %%
sns.regplot(data = corr_look, x = 'elapsed_time_ratio', y = 'cor_ratio', color = 'green')
# Out:
# <AxesSubplot: xlabel='elapsed_time_ratio', ylabel='cor_ratio'>

# %% [markdown]
# ## На успеваемость студентов влияют следующие характеристики:
# - количество ответов студентов, большее медианного значения количества ответов, равного 55
# - типа контента (вопрос или лекция) - очень слабо
# - соотношения количества правильных ответов и среднего времени ответа на каждый вопрос к общему количеству ответов студентов - слабо
